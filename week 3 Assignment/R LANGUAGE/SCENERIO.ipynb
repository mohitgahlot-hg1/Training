# %% [markdown]
# 2 📈 Problem Scenario: Stock Data Analysis with Quantmod
#
# Background
#
# An investment firm wants to analyze stock performance trends using R language to support trading decisions. Analysts need to retrieve historical stock prices, visualize trends, and apply technical indicators (like moving averages and Bollinger Bands) to identify potential buy/sell signals.
#
# Objective
#
# Use the quantmod package to fetch stock data directly from Yahoo Finance.
#
# Perform time series analysis of stock prices.
#
# Visualize stock trends with candlestick charts and overlays of technical indicators.
#
# Summarize insights for traders to make informed decisions.
